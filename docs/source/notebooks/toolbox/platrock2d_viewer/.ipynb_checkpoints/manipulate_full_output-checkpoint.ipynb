# %% [markdown]
# # Manipulation du fichier de  résultats en sortie de PlatRock2D

# %% [markdown]
# **Dépendances:**
# - [tables](https://pypi.org/project/tables/)
#
# > PyTables is a package for managing hierarchical datasets and designed to efficiently cope with extremely large amounts of data. PyTables is built on top of the HDF5 library and the NumPy package and features an object-oriented interface that, combined with C-code generated from Cython sources, makes of it a fast, yet extremely easy to use tool for interactively save and retrieve large amounts of data.

# %%
import tables

# %% [markdown]
# ### Ouverture du fichier de résultats *full_output.hdf5*

# %%
hdf5_file = tables.open_file("full_output.hdf5")

# %% [markdown]
# ### Contenu du fichier

# %%
#print(hdf5_file)
# Out:
# full_output.hdf5 (File) ''
# Last modif.: '2022-12-14T13:01:30+00:00'
# Object Tree:
# / (RootGroup) ''
# /checkpoints (Group) ''
# /checkpoints/600.0 (Array(247, 5)) ''
# /checkpoints/785.0 (Array(0,)) ''
# /rocks (Group) ''
# /rocks/start_data (Array(1000, 3)) ''
# /rocks/contacts (Group) ''
# /rocks/contacts/0 (Array(24, 8)) ''
# /rocks/contacts/1 (Array(18, 8)) ''
# /rocks/contacts/10 (Array(19, 8)) ''
# /rocks/contacts/100 (Array(21, 8)) ''
# /rocks/contacts/101 (Array(26, 8)) ''
# /rocks/contacts/102 (Array(21, 8)) ''
# /rocks/contacts/103 (Array(23, 8)) ''
# /rocks/contacts/104 (Array(19, 8)) ''
# /rocks/contacts/105 (Array(19, 8)) ''
# /rocks/contacts/106 (Array(22, 8)) ''
# /rocks/contacts/107 (Array(21, 8)) ''
# /rocks/contacts/108 (Array(52, 8)) ''
# /rocks/contacts/109 (Array(16, 8)) ''
# /rocks/contacts/11 (Array(24, 8)) ''
# /rocks/contacts/110 (Array(30, 8)) ''
# /rocks/contacts/111 (Array(20, 8)) ''
# /rocks/contacts/112 (Array(26, 8)) ''
# /rocks/contacts/113 (Array(26, 8)) ''
# /rocks/contacts/114 (Array(18, 8)) ''
# /rocks/contacts/115 (Array(27, 8)) ''
# /rocks/contacts/116 (Array(21, 8)) ''
# /rocks/contacts/117 (Array(18, 8)) ''
# /rocks/contacts/118 (Array(23, 8)) ''
# /rocks/contacts/119 (Array(21, 8)) ''
# /rocks/contacts/12 (Array(18, 8)) ''
# /rocks/contacts/120 (Array(21, 8)) ''
# /rocks/contacts/121 (Array(21, 8)) ''
# /rocks/contacts/122 (Array(22, 8)) ''
# /rocks/contacts/123 (Array(23, 8)) ''
# /rocks/contacts/124 (Array(25, 8)) ''
# /rocks/contacts/125 (Array(19, 8)) ''
# /rocks/contacts/126 (Array(19, 8)) ''
# /rocks/contacts/127 (Array(18, 8)) ''
# /rocks/contacts/128 (Array(24, 8)) ''
# /rocks/contacts/129 (Array(25, 8)) ''
# /rocks/contacts/13 (Array(19, 8)) ''
# /rocks/contacts/130 (Array(21, 8)) ''
# /rocks/contacts/131 (Array(22, 8)) ''
# /rocks/contacts/132 (Array(44, 8)) ''
# /rocks/contacts/133 (Array(25, 8)) ''
# /rocks/contacts/134 (Array(23, 8)) ''
# /rocks/contacts/135 (Array(22, 8)) ''
# /rocks/contacts/136 (Array(21, 8)) ''
# /rocks/contacts/137 (Array(20, 8)) ''
# /rocks/contacts/138 (Array(20, 8)) ''
# /rocks/contacts/139 (Array(23, 8)) ''
# /rocks/contacts/14 (Array(21, 8)) ''
# /rocks/contacts/140 (Array(20, 8)) ''
# /rocks/contacts/141 (Array(21, 8)) ''
# /rocks/contacts/142 (Array(23, 8)) ''
# /rocks/contacts/143 (Array(21, 8)) ''
# /rocks/contacts/144 (Array(25, 8)) ''
# /rocks/contacts/145 (Array(25, 8)) ''
# /rocks/contacts/146 (Array(26, 8)) ''
# /rocks/contacts/147 (Array(47, 8)) ''
# /rocks/contacts/148 (Array(34, 8)) ''
# /rocks/contacts/149 (Array(24, 8)) ''
# /rocks/contacts/15 (Array(26, 8)) ''
# /rocks/contacts/150 (Array(22, 8)) ''
# /rocks/contacts/151 (Array(22, 8)) ''
# /rocks/contacts/152 (Array(22, 8)) ''
# /rocks/contacts/153 (Array(19, 8)) ''
# /rocks/contacts/154 (Array(19, 8)) ''
# /rocks/contacts/155 (Array(21, 8)) ''
# /rocks/contacts/156 (Array(23, 8)) ''
# /rocks/contacts/157 (Array(20, 8)) ''
# /rocks/contacts/158 (Array(21, 8)) ''
# /rocks/contacts/159 (Array(22, 8)) ''
# /rocks/contacts/16 (Array(22, 8)) ''
# /rocks/contacts/160 (Array(21, 8)) ''
# /rocks/contacts/161 (Array(20, 8)) ''
# /rocks/contacts/162 (Array(23, 8)) ''
# /rocks/contacts/163 (Array(17, 8)) ''
# /rocks/contacts/164 (Array(28, 8)) ''
# /rocks/contacts/165 (Array(22, 8)) ''
# /rocks/contacts/166 (Array(17, 8)) ''
# /rocks/contacts/167 (Array(21, 8)) ''
# /rocks/contacts/168 (Array(20, 8)) ''
# /rocks/contacts/169 (Array(22, 8)) ''
# /rocks/contacts/17 (Array(23, 8)) ''
# /rocks/contacts/170 (Array(26, 8)) ''
# /rocks/contacts/171 (Array(19, 8)) ''
# /rocks/contacts/172 (Array(20, 8)) ''
# /rocks/contacts/173 (Array(25, 8)) ''
# /rocks/contacts/174 (Array(22, 8)) ''
# /rocks/contacts/175 (Array(27, 8)) ''
# /rocks/contacts/176 (Array(23, 8)) ''
# /rocks/contacts/177 (Array(38, 8)) ''
# /rocks/contacts/178 (Array(29, 8)) ''
# /rocks/contacts/179 (Array(20, 8)) ''
# /rocks/contacts/18 (Array(20, 8)) ''
# /rocks/contacts/180 (Array(25, 8)) ''
# /rocks/contacts/181 (Array(18, 8)) ''
# /rocks/contacts/182 (Array(25, 8)) ''
# /rocks/contacts/183 (Array(19, 8)) ''
# /rocks/contacts/184 (Array(20, 8)) ''
# /rocks/contacts/185 (Array(22, 8)) ''
# /rocks/contacts/186 (Array(21, 8)) ''
# /rocks/contacts/187 (Array(27, 8)) ''
# /rocks/contacts/188 (Array(21, 8)) ''
# /rocks/contacts/189 (Array(22, 8)) ''
# /rocks/contacts/19 (Array(18, 8)) ''
# /rocks/contacts/190 (Array(21, 8)) ''
# /rocks/contacts/191 (Array(45, 8)) ''
# /rocks/contacts/192 (Array(18, 8)) ''
# /rocks/contacts/193 (Array(16, 8)) ''
# /rocks/contacts/194 (Array(23, 8)) ''
# /rocks/contacts/195 (Array(20, 8)) ''
# /rocks/contacts/196 (Array(23, 8)) ''
# /rocks/contacts/197 (Array(25, 8)) ''
# /rocks/contacts/198 (Array(23, 8)) ''
# /rocks/contacts/199 (Array(47, 8)) ''
# /rocks/contacts/2 (Array(19, 8)) ''
# /rocks/contacts/20 (Array(21, 8)) ''
# /rocks/contacts/200 (Array(26, 8)) ''
# /rocks/contacts/201 (Array(27, 8)) ''
# /rocks/contacts/202 (Array(23, 8)) ''
# /rocks/contacts/203 (Array(36, 8)) ''
# /rocks/contacts/204 (Array(27, 8)) ''
# /rocks/contacts/205 (Array(27, 8)) ''
# /rocks/contacts/206 (Array(21, 8)) ''
# /rocks/contacts/207 (Array(28, 8)) ''
# /rocks/contacts/208 (Array(25, 8)) ''
# /rocks/contacts/209 (Array(21, 8)) ''
# /rocks/contacts/21 (Array(27, 8)) ''
# /rocks/contacts/210 (Array(37, 8)) ''
# /rocks/contacts/211 (Array(21, 8)) ''
# /rocks/contacts/212 (Array(20, 8)) ''
# /rocks/contacts/213 (Array(20, 8)) ''
# /rocks/contacts/214 (Array(21, 8)) ''
# /rocks/contacts/215 (Array(25, 8)) ''
# /rocks/contacts/216 (Array(29, 8)) ''
# /rocks/contacts/217 (Array(25, 8)) ''
# /rocks/contacts/218 (Array(19, 8)) ''
# /rocks/contacts/219 (Array(29, 8)) ''
# /rocks/contacts/22 (Array(19, 8)) ''
# /rocks/contacts/220 (Array(21, 8)) ''
# /rocks/contacts/221 (Array(17, 8)) ''
# /rocks/contacts/222 (Array(22, 8)) ''
# /rocks/contacts/223 (Array(49, 8)) ''
# /rocks/contacts/224 (Array(21, 8)) ''
# /rocks/contacts/225 (Array(18, 8)) ''
# /rocks/contacts/226 (Array(29, 8)) ''
# /rocks/contacts/227 (Array(23, 8)) ''
# /rocks/contacts/228 (Array(22, 8)) ''
# /rocks/contacts/229 (Array(19, 8)) ''
# /rocks/contacts/23 (Array(29, 8)) ''
# /rocks/contacts/230 (Array(22, 8)) ''
# /rocks/contacts/231 (Array(28, 8)) ''
# /rocks/contacts/232 (Array(25, 8)) ''
# /rocks/contacts/233 (Array(23, 8)) ''
# /rocks/contacts/234 (Array(26, 8)) ''
# /rocks/contacts/235 (Array(25, 8)) ''
# /rocks/contacts/236 (Array(17, 8)) ''
# /rocks/contacts/237 (Array(22, 8)) ''
# /rocks/contacts/238 (Array(20, 8)) ''
# /rocks/contacts/239 (Array(24, 8)) ''
# /rocks/contacts/24 (Array(24, 8)) ''
# /rocks/contacts/240 (Array(28, 8)) ''
# /rocks/contacts/241 (Array(25, 8)) ''
# /rocks/contacts/242 (Array(26, 8)) ''
# /rocks/contacts/243 (Array(26, 8)) ''
# /rocks/contacts/244 (Array(28, 8)) ''
# /rocks/contacts/245 (Array(20, 8)) ''
# /rocks/contacts/246 (Array(24, 8)) ''
# /rocks/contacts/247 (Array(21, 8)) ''
# /rocks/contacts/248 (Array(20, 8)) ''
# /rocks/contacts/249 (Array(25, 8)) ''
# /rocks/contacts/25 (Array(23, 8)) ''
# /rocks/contacts/250 (Array(21, 8)) ''
# /rocks/contacts/251 (Array(25, 8)) ''
# /rocks/contacts/252 (Array(17, 8)) ''
# /rocks/contacts/253 (Array(20, 8)) ''
# /rocks/contacts/254 (Array(24, 8)) ''
# /rocks/contacts/255 (Array(25, 8)) ''
# /rocks/contacts/256 (Array(18, 8)) ''
# /rocks/contacts/257 (Array(22, 8)) ''
# /rocks/contacts/258 (Array(38, 8)) ''
# /rocks/contacts/259 (Array(27, 8)) ''
# /rocks/contacts/26 (Array(21, 8)) ''
# /rocks/contacts/260 (Array(18, 8)) ''
# /rocks/contacts/261 (Array(24, 8)) ''
# /rocks/contacts/262 (Array(24, 8)) ''
# /rocks/contacts/263 (Array(20, 8)) ''
# /rocks/contacts/264 (Array(20, 8)) ''
# /rocks/contacts/265 (Array(23, 8)) ''
# /rocks/contacts/266 (Array(24, 8)) ''
# /rocks/contacts/267 (Array(24, 8)) ''
# /rocks/contacts/268 (Array(23, 8)) ''
# /rocks/contacts/269 (Array(22, 8)) ''
# /rocks/contacts/27 (Array(24, 8)) ''
# /rocks/contacts/270 (Array(23, 8)) ''
# /rocks/contacts/271 (Array(19, 8)) ''
# /rocks/contacts/272 (Array(21, 8)) ''
# /rocks/contacts/273 (Array(27, 8)) ''
# /rocks/contacts/274 (Array(18, 8)) ''
# /rocks/contacts/275 (Array(20, 8)) ''
# /rocks/contacts/276 (Array(25, 8)) ''
# /rocks/contacts/277 (Array(22, 8)) ''
# /rocks/contacts/278 (Array(20, 8)) ''
# /rocks/contacts/279 (Array(24, 8)) ''
# /rocks/contacts/28 (Array(23, 8)) ''
# /rocks/contacts/280 (Array(22, 8)) ''
# /rocks/contacts/281 (Array(21, 8)) ''
# /rocks/contacts/282 (Array(22, 8)) ''
# /rocks/contacts/283 (Array(19, 8)) ''
# /rocks/contacts/284 (Array(50, 8)) ''
# /rocks/contacts/285 (Array(22, 8)) ''
# /rocks/contacts/286 (Array(45, 8)) ''
# /rocks/contacts/287 (Array(23, 8)) ''
# /rocks/contacts/288 (Array(26, 8)) ''
# /rocks/contacts/289 (Array(25, 8)) ''
# /rocks/contacts/29 (Array(19, 8)) ''
# /rocks/contacts/290 (Array(26, 8)) ''
# /rocks/contacts/291 (Array(28, 8)) ''
# /rocks/contacts/292 (Array(25, 8)) ''
# /rocks/contacts/293 (Array(21, 8)) ''
# /rocks/contacts/294 (Array(28, 8)) ''
# /rocks/contacts/295 (Array(37, 8)) ''
# /rocks/contacts/296 (Array(21, 8)) ''
# /rocks/contacts/297 (Array(40, 8)) ''
# /rocks/contacts/298 (Array(22, 8)) ''
# /rocks/contacts/299 (Array(26, 8)) ''
# /rocks/contacts/3 (Array(24, 8)) ''
# /rocks/contacts/30 (Array(22, 8)) ''
# /rocks/contacts/300 (Array(31, 8)) ''
# /rocks/contacts/301 (Array(22, 8)) ''
# /rocks/contacts/302 (Array(22, 8)) ''
# /rocks/contacts/303 (Array(23, 8)) ''
# /rocks/contacts/304 (Array(19, 8)) ''
# /rocks/contacts/305 (Array(24, 8)) ''
# /rocks/contacts/306 (Array(20, 8)) ''
# /rocks/contacts/307 (Array(25, 8)) ''
# /rocks/contacts/308 (Array(23, 8)) ''
# /rocks/contacts/309 (Array(22, 8)) ''
# /rocks/contacts/31 (Array(21, 8)) ''
# /rocks/contacts/310 (Array(19, 8)) ''
# /rocks/contacts/311 (Array(18, 8)) ''
# /rocks/contacts/312 (Array(24, 8)) ''
# /rocks/contacts/313 (Array(18, 8)) ''
# /rocks/contacts/314 (Array(19, 8)) ''
# /rocks/contacts/315 (Array(23, 8)) ''
# /rocks/contacts/316 (Array(17, 8)) ''
# /rocks/contacts/317 (Array(20, 8)) ''
# /rocks/contacts/318 (Array(24, 8)) ''
# /rocks/contacts/319 (Array(43, 8)) ''
# /rocks/contacts/32 (Array(22, 8)) ''
# /rocks/contacts/320 (Array(24, 8)) ''
# /rocks/contacts/321 (Array(21, 8)) ''
# /rocks/contacts/322 (Array(20, 8)) ''
# /rocks/contacts/323 (Array(19, 8)) ''
# /rocks/contacts/324 (Array(21, 8)) ''
# /rocks/contacts/325 (Array(24, 8)) ''
# /rocks/contacts/326 (Array(22, 8)) ''
# /rocks/contacts/327 (Array(40, 8)) ''
# /rocks/contacts/328 (Array(19, 8)) ''
# /rocks/contacts/329 (Array(26, 8)) ''
# /rocks/contacts/33 (Array(23, 8)) ''
# /rocks/contacts/330 (Array(20, 8)) ''
# /rocks/contacts/331 (Array(22, 8)) ''
# /rocks/contacts/332 (Array(25, 8)) ''
# /rocks/contacts/333 (Array(26, 8)) ''
# /rocks/contacts/334 (Array(26, 8)) ''
# /rocks/contacts/335 (Array(45, 8)) ''
# /rocks/contacts/336 (Array(25, 8)) ''
# /rocks/contacts/337 (Array(20, 8)) ''
# /rocks/contacts/338 (Array(23, 8)) ''
# /rocks/contacts/339 (Array(24, 8)) ''
# /rocks/contacts/34 (Array(24, 8)) ''
# /rocks/contacts/340 (Array(24, 8)) ''
# /rocks/contacts/341 (Array(31, 8)) ''
# /rocks/contacts/342 (Array(24, 8)) ''
# /rocks/contacts/343 (Array(25, 8)) ''
# /rocks/contacts/344 (Array(20, 8)) ''
# /rocks/contacts/345 (Array(23, 8)) ''
# /rocks/contacts/346 (Array(18, 8)) ''
# /rocks/contacts/347 (Array(18, 8)) ''
# /rocks/contacts/348 (Array(51, 8)) ''
# /rocks/contacts/349 (Array(20, 8)) ''
# /rocks/contacts/35 (Array(23, 8)) ''
# /rocks/contacts/350 (Array(21, 8)) ''
# /rocks/contacts/351 (Array(26, 8)) ''
# /rocks/contacts/352 (Array(26, 8)) ''
# /rocks/contacts/353 (Array(23, 8)) ''
# /rocks/contacts/354 (Array(21, 8)) ''
# /rocks/contacts/355 (Array(25, 8)) ''
# /rocks/contacts/356 (Array(22, 8)) ''
# /rocks/contacts/357 (Array(18, 8)) ''
# /rocks/contacts/358 (Array(22, 8)) ''
# /rocks/contacts/359 (Array(25, 8)) ''
# /rocks/contacts/36 (Array(23, 8)) ''
# /rocks/contacts/360 (Array(29, 8)) ''
# /rocks/contacts/361 (Array(21, 8)) ''
# /rocks/contacts/362 (Array(20, 8)) ''
# /rocks/contacts/363 (Array(32, 8)) ''
# /rocks/contacts/364 (Array(19, 8)) ''
# /rocks/contacts/365 (Array(25, 8)) ''
# /rocks/contacts/366 (Array(27, 8)) ''
# /rocks/contacts/367 (Array(21, 8)) ''
# /rocks/contacts/368 (Array(28, 8)) ''
# /rocks/contacts/369 (Array(24, 8)) ''
# /rocks/contacts/37 (Array(24, 8)) ''
# /rocks/contacts/370 (Array(22, 8)) ''
# /rocks/contacts/371 (Array(21, 8)) ''
# /rocks/contacts/372 (Array(23, 8)) ''
# /rocks/contacts/373 (Array(21, 8)) ''
# /rocks/contacts/374 (Array(29, 8)) ''
# /rocks/contacts/375 (Array(20, 8)) ''
# /rocks/contacts/376 (Array(19, 8)) ''
# /rocks/contacts/377 (Array(20, 8)) ''
# /rocks/contacts/378 (Array(22, 8)) ''
# /rocks/contacts/379 (Array(25, 8)) ''
# /rocks/contacts/38 (Array(35, 8)) ''
# /rocks/contacts/380 (Array(23, 8)) ''
# /rocks/contacts/381 (Array(26, 8)) ''
# /rocks/contacts/382 (Array(28, 8)) ''
# /rocks/contacts/383 (Array(25, 8)) ''
# /rocks/contacts/384 (Array(25, 8)) ''
# /rocks/contacts/385 (Array(17, 8)) ''
# /rocks/contacts/386 (Array(22, 8)) ''
# /rocks/contacts/387 (Array(28, 8)) ''
# /rocks/contacts/388 (Array(21, 8)) ''
# /rocks/contacts/389 (Array(26, 8)) ''
# /rocks/contacts/39 (Array(20, 8)) ''
# /rocks/contacts/390 (Array(25, 8)) ''
# /rocks/contacts/391 (Array(25, 8)) ''
# /rocks/contacts/392 (Array(27, 8)) ''
# /rocks/contacts/393 (Array(28, 8)) ''
# /rocks/contacts/394 (Array(18, 8)) ''
# /rocks/contacts/395 (Array(19, 8)) ''
# /rocks/contacts/396 (Array(22, 8)) ''
# /rocks/contacts/397 (Array(19, 8)) ''
# /rocks/contacts/398 (Array(20, 8)) ''
# /rocks/contacts/399 (Array(20, 8)) ''
# /rocks/contacts/4 (Array(19, 8)) ''
# /rocks/contacts/40 (Array(17, 8)) ''
# /rocks/contacts/400 (Array(20, 8)) ''
# /rocks/contacts/401 (Array(25, 8)) ''
# /rocks/contacts/402 (Array(21, 8)) ''
# /rocks/contacts/403 (Array(22, 8)) ''
# /rocks/contacts/404 (Array(20, 8)) ''
# /rocks/contacts/405 (Array(23, 8)) ''
# /rocks/contacts/406 (Array(24, 8)) ''
# /rocks/contacts/407 (Array(18, 8)) ''
# /rocks/contacts/408 (Array(21, 8)) ''
# /rocks/contacts/409 (Array(27, 8)) ''
# /rocks/contacts/41 (Array(24, 8)) ''
# /rocks/contacts/410 (Array(20, 8)) ''
# /rocks/contacts/411 (Array(21, 8)) ''
# /rocks/contacts/412 (Array(25, 8)) ''
# /rocks/contacts/413 (Array(21, 8)) ''
# /rocks/contacts/414 (Array(45, 8)) ''
# /rocks/contacts/415 (Array(25, 8)) ''
# /rocks/contacts/416 (Array(41, 8)) ''
# /rocks/contacts/417 (Array(48, 8)) ''
# /rocks/contacts/418 (Array(27, 8)) ''
# /rocks/contacts/419 (Array(25, 8)) ''
# /rocks/contacts/42 (Array(25, 8)) ''
# /rocks/contacts/420 (Array(45, 8)) ''
# /rocks/contacts/421 (Array(26, 8)) ''
# /rocks/contacts/422 (Array(28, 8)) ''
# /rocks/contacts/423 (Array(45, 8)) ''
# /rocks/contacts/424 (Array(22, 8)) ''
# /rocks/contacts/425 (Array(21, 8)) ''
# /rocks/contacts/426 (Array(25, 8)) ''
# /rocks/contacts/427 (Array(23, 8)) ''
# /rocks/contacts/428 (Array(20, 8)) ''
# /rocks/contacts/429 (Array(22, 8)) ''
# /rocks/contacts/43 (Array(22, 8)) ''
# /rocks/contacts/430 (Array(44, 8)) ''
# /rocks/contacts/431 (Array(26, 8)) ''
# /rocks/contacts/432 (Array(21, 8)) ''
# /rocks/contacts/433 (Array(28, 8)) ''
# /rocks/contacts/434 (Array(29, 8)) ''
# /rocks/contacts/435 (Array(22, 8)) ''
# /rocks/contacts/436 (Array(26, 8)) ''
# /rocks/contacts/437 (Array(19, 8)) ''
# /rocks/contacts/438 (Array(26, 8)) ''
# /rocks/contacts/439 (Array(22, 8)) ''
# /rocks/contacts/44 (Array(23, 8)) ''
# /rocks/contacts/440 (Array(21, 8)) ''
# /rocks/contacts/441 (Array(27, 8)) ''
# /rocks/contacts/442 (Array(20, 8)) ''
# /rocks/contacts/443 (Array(20, 8)) ''
# /rocks/contacts/444 (Array(23, 8)) ''
# /rocks/contacts/445 (Array(21, 8)) ''
# /rocks/contacts/446 (Array(25, 8)) ''
# /rocks/contacts/447 (Array(31, 8)) ''
# /rocks/contacts/448 (Array(24, 8)) ''
# /rocks/contacts/449 (Array(25, 8)) ''
# /rocks/contacts/45 (Array(26, 8)) ''
# /rocks/contacts/450 (Array(20, 8)) ''
# /rocks/contacts/451 (Array(20, 8)) ''
# /rocks/contacts/452 (Array(24, 8)) ''
# /rocks/contacts/453 (Array(27, 8)) ''
# /rocks/contacts/454 (Array(22, 8)) ''
# /rocks/contacts/455 (Array(24, 8)) ''
# /rocks/contacts/456 (Array(21, 8)) ''
# /rocks/contacts/457 (Array(20, 8)) ''
# /rocks/contacts/458 (Array(25, 8)) ''
# /rocks/contacts/459 (Array(32, 8)) ''
# /rocks/contacts/46 (Array(26, 8)) ''
# /rocks/contacts/460 (Array(26, 8)) ''
# /rocks/contacts/461 (Array(22, 8)) ''
# /rocks/contacts/462 (Array(22, 8)) ''
# /rocks/contacts/463 (Array(24, 8)) ''
# /rocks/contacts/464 (Array(19, 8)) ''
# /rocks/contacts/465 (Array(26, 8)) ''
# /rocks/contacts/466 (Array(20, 8)) ''
# /rocks/contacts/467 (Array(21, 8)) ''
# /rocks/contacts/468 (Array(31, 8)) ''
# /rocks/contacts/469 (Array(19, 8)) ''
# /rocks/contacts/47 (Array(21, 8)) ''
# /rocks/contacts/470 (Array(22, 8)) ''
# /rocks/contacts/471 (Array(23, 8)) ''
# /rocks/contacts/472 (Array(26, 8)) ''
# /rocks/contacts/473 (Array(19, 8)) ''
# /rocks/contacts/474 (Array(25, 8)) ''
# /rocks/contacts/475 (Array(22, 8)) ''
# /rocks/contacts/476 (Array(27, 8)) ''
# /rocks/contacts/477 (Array(18, 8)) ''
# /rocks/contacts/478 (Array(24, 8)) ''
# /rocks/contacts/479 (Array(26, 8)) ''
# /rocks/contacts/48 (Array(21, 8)) ''
# /rocks/contacts/480 (Array(21, 8)) ''
# /rocks/contacts/481 (Array(20, 8)) ''
# /rocks/contacts/482 (Array(20, 8)) ''
# /rocks/contacts/483 (Array(22, 8)) ''
# /rocks/contacts/484 (Array(17, 8)) ''
# /rocks/contacts/485 (Array(28, 8)) ''
# /rocks/contacts/486 (Array(28, 8)) ''
# /rocks/contacts/487 (Array(26, 8)) ''
# /rocks/contacts/488 (Array(21, 8)) ''
# /rocks/contacts/489 (Array(39, 8)) ''
# /rocks/contacts/49 (Array(19, 8)) ''
# /rocks/contacts/490 (Array(25, 8)) ''
# /rocks/contacts/491 (Array(21, 8)) ''
# /rocks/contacts/492 (Array(25, 8)) ''
# /rocks/contacts/493 (Array(19, 8)) ''
# /rocks/contacts/494 (Array(23, 8)) ''
# /rocks/contacts/495 (Array(21, 8)) ''
# /rocks/contacts/496 (Array(25, 8)) ''
# /rocks/contacts/497 (Array(16, 8)) ''
# /rocks/contacts/498 (Array(23, 8)) ''
# /rocks/contacts/499 (Array(26, 8)) ''
# /rocks/contacts/5 (Array(29, 8)) ''
# /rocks/contacts/50 (Array(24, 8)) ''
# /rocks/contacts/500 (Array(21, 8)) ''
# /rocks/contacts/501 (Array(26, 8)) ''
# /rocks/contacts/502 (Array(23, 8)) ''
# /rocks/contacts/503 (Array(19, 8)) ''
# /rocks/contacts/504 (Array(17, 8)) ''
# /rocks/contacts/505 (Array(28, 8)) ''
# /rocks/contacts/506 (Array(19, 8)) ''
# /rocks/contacts/507 (Array(25, 8)) ''
# /rocks/contacts/508 (Array(21, 8)) ''
# /rocks/contacts/509 (Array(31, 8)) ''
# /rocks/contacts/51 (Array(18, 8)) ''
# /rocks/contacts/510 (Array(19, 8)) ''
# /rocks/contacts/511 (Array(17, 8)) ''
# /rocks/contacts/512 (Array(23, 8)) ''
# /rocks/contacts/513 (Array(20, 8)) ''
# /rocks/contacts/514 (Array(20, 8)) ''
# /rocks/contacts/515 (Array(23, 8)) ''
# /rocks/contacts/516 (Array(21, 8)) ''
# /rocks/contacts/517 (Array(23, 8)) ''
# /rocks/contacts/518 (Array(21, 8)) ''
# /rocks/contacts/519 (Array(20, 8)) ''
# /rocks/contacts/52 (Array(24, 8)) ''
# /rocks/contacts/520 (Array(23, 8)) ''
# /rocks/contacts/521 (Array(37, 8)) ''
# /rocks/contacts/522 (Array(22, 8)) ''
# /rocks/contacts/523 (Array(22, 8)) ''
# /rocks/contacts/524 (Array(27, 8)) ''
# /rocks/contacts/525 (Array(21, 8)) ''
# /rocks/contacts/526 (Array(18, 8)) ''
# /rocks/contacts/527 (Array(30, 8)) ''
# /rocks/contacts/528 (Array(26, 8)) ''
# /rocks/contacts/529 (Array(23, 8)) ''
# /rocks/contacts/53 (Array(17, 8)) ''
# /rocks/contacts/530 (Array(21, 8)) ''
# /rocks/contacts/531 (Array(23, 8)) ''
# /rocks/contacts/532 (Array(24, 8)) ''
# /rocks/contacts/533 (Array(18, 8)) ''
# /rocks/contacts/534 (Array(27, 8)) ''
# /rocks/contacts/535 (Array(20, 8)) ''
# /rocks/contacts/536 (Array(34, 8)) ''
# /rocks/contacts/537 (Array(20, 8)) ''
# /rocks/contacts/538 (Array(25, 8)) ''
# /rocks/contacts/539 (Array(25, 8)) ''
# /rocks/contacts/54 (Array(25, 8)) ''
# /rocks/contacts/540 (Array(26, 8)) ''
# /rocks/contacts/541 (Array(28, 8)) ''
# /rocks/contacts/542 (Array(18, 8)) ''
# /rocks/contacts/543 (Array(19, 8)) ''
# /rocks/contacts/544 (Array(26, 8)) ''
# /rocks/contacts/545 (Array(20, 8)) ''
# /rocks/contacts/546 (Array(19, 8)) ''
# /rocks/contacts/547 (Array(20, 8)) ''
# /rocks/contacts/548 (Array(25, 8)) ''
# /rocks/contacts/549 (Array(36, 8)) ''
# /rocks/contacts/55 (Array(20, 8)) ''
# /rocks/contacts/550 (Array(28, 8)) ''
# /rocks/contacts/551 (Array(21, 8)) ''
# /rocks/contacts/552 (Array(21, 8)) ''
# /rocks/contacts/553 (Array(21, 8)) ''
# /rocks/contacts/554 (Array(20, 8)) ''
# /rocks/contacts/555 (Array(24, 8)) ''
# /rocks/contacts/556 (Array(22, 8)) ''
# /rocks/contacts/557 (Array(27, 8)) ''
# /rocks/contacts/558 (Array(22, 8)) ''
# /rocks/contacts/559 (Array(19, 8)) ''
# /rocks/contacts/56 (Array(23, 8)) ''
# /rocks/contacts/560 (Array(22, 8)) ''
# /rocks/contacts/561 (Array(26, 8)) ''
# /rocks/contacts/562 (Array(26, 8)) ''
# /rocks/contacts/563 (Array(21, 8)) ''
# /rocks/contacts/564 (Array(22, 8)) ''
# /rocks/contacts/565 (Array(21, 8)) ''
# /rocks/contacts/566 (Array(23, 8)) ''
# /rocks/contacts/567 (Array(20, 8)) ''
# /rocks/contacts/568 (Array(26, 8)) ''
# /rocks/contacts/569 (Array(56, 8)) ''
# /rocks/contacts/57 (Array(18, 8)) ''
# /rocks/contacts/570 (Array(38, 8)) ''
# /rocks/contacts/571 (Array(23, 8)) ''
# /rocks/contacts/572 (Array(36, 8)) ''
# /rocks/contacts/573 (Array(30, 8)) ''
# /rocks/contacts/574 (Array(23, 8)) ''
# /rocks/contacts/575 (Array(17, 8)) ''
# /rocks/contacts/576 (Array(20, 8)) ''
# /rocks/contacts/577 (Array(22, 8)) ''
# /rocks/contacts/578 (Array(48, 8)) ''
# /rocks/contacts/579 (Array(20, 8)) ''
# /rocks/contacts/58 (Array(23, 8)) ''
# /rocks/contacts/580 (Array(17, 8)) ''
# /rocks/contacts/581 (Array(27, 8)) ''
# /rocks/contacts/582 (Array(22, 8)) ''
# /rocks/contacts/583 (Array(20, 8)) ''
# /rocks/contacts/584 (Array(26, 8)) ''
# /rocks/contacts/585 (Array(22, 8)) ''
# /rocks/contacts/586 (Array(19, 8)) ''
# /rocks/contacts/587 (Array(19, 8)) ''
# /rocks/contacts/588 (Array(21, 8)) ''
# /rocks/contacts/589 (Array(22, 8)) ''
# /rocks/contacts/59 (Array(22, 8)) ''
# /rocks/contacts/590 (Array(21, 8)) ''
# /rocks/contacts/591 (Array(27, 8)) ''
# /rocks/contacts/592 (Array(30, 8)) ''
# /rocks/contacts/593 (Array(23, 8)) ''
# /rocks/contacts/594 (Array(21, 8)) ''
# /rocks/contacts/595 (Array(25, 8)) ''
# /rocks/contacts/596 (Array(22, 8)) ''
# /rocks/contacts/597 (Array(27, 8)) ''
# /rocks/contacts/598 (Array(24, 8)) ''
# /rocks/contacts/599 (Array(26, 8)) ''
# /rocks/contacts/6 (Array(29, 8)) ''
# /rocks/contacts/60 (Array(25, 8)) ''
# /rocks/contacts/600 (Array(23, 8)) ''
# /rocks/contacts/601 (Array(21, 8)) ''
# /rocks/contacts/602 (Array(20, 8)) ''
# /rocks/contacts/603 (Array(26, 8)) ''
# /rocks/contacts/604 (Array(28, 8)) ''
# /rocks/contacts/605 (Array(21, 8)) ''
# /rocks/contacts/606 (Array(19, 8)) ''
# /rocks/contacts/607 (Array(44, 8)) ''
# /rocks/contacts/608 (Array(21, 8)) ''
# /rocks/contacts/609 (Array(25, 8)) ''
# /rocks/contacts/61 (Array(27, 8)) ''
# /rocks/contacts/610 (Array(46, 8)) ''
# /rocks/contacts/611 (Array(22, 8)) ''
# /rocks/contacts/612 (Array(21, 8)) ''
# /rocks/contacts/613 (Array(26, 8)) ''
# /rocks/contacts/614 (Array(24, 8)) ''
# /rocks/contacts/615 (Array(18, 8)) ''
# /rocks/contacts/616 (Array(24, 8)) ''
# /rocks/contacts/617 (Array(29, 8)) ''
# /rocks/contacts/618 (Array(25, 8)) ''
# /rocks/contacts/619 (Array(26, 8)) ''
# /rocks/contacts/62 (Array(21, 8)) ''
# /rocks/contacts/620 (Array(20, 8)) ''
# /rocks/contacts/621 (Array(23, 8)) ''
# /rocks/contacts/622 (Array(24, 8)) ''
# /rocks/contacts/623 (Array(21, 8)) ''
# /rocks/contacts/624 (Array(27, 8)) ''
# /rocks/contacts/625 (Array(22, 8)) ''
# /rocks/contacts/626 (Array(24, 8)) ''
# /rocks/contacts/627 (Array(24, 8)) ''
# /rocks/contacts/628 (Array(20, 8)) ''
# /rocks/contacts/629 (Array(26, 8)) ''
# /rocks/contacts/63 (Array(18, 8)) ''
# /rocks/contacts/630 (Array(18, 8)) ''
# /rocks/contacts/631 (Array(24, 8)) ''
# /rocks/contacts/632 (Array(24, 8)) ''
# /rocks/contacts/633 (Array(24, 8)) ''
# /rocks/contacts/634 (Array(23, 8)) ''
# /rocks/contacts/635 (Array(20, 8)) ''
# /rocks/contacts/636 (Array(23, 8)) ''
# /rocks/contacts/637 (Array(24, 8)) ''
# /rocks/contacts/638 (Array(25, 8)) ''
# /rocks/contacts/639 (Array(21, 8)) ''
# /rocks/contacts/64 (Array(24, 8)) ''
# /rocks/contacts/640 (Array(28, 8)) ''
# /rocks/contacts/641 (Array(21, 8)) ''
# /rocks/contacts/642 (Array(24, 8)) ''
# /rocks/contacts/643 (Array(18, 8)) ''
# /rocks/contacts/644 (Array(29, 8)) ''
# /rocks/contacts/645 (Array(30, 8)) ''
# /rocks/contacts/646 (Array(27, 8)) ''
# /rocks/contacts/647 (Array(28, 8)) ''
# /rocks/contacts/648 (Array(20, 8)) ''
# /rocks/contacts/649 (Array(26, 8)) ''
# /rocks/contacts/65 (Array(44, 8)) ''
# /rocks/contacts/650 (Array(22, 8)) ''
# /rocks/contacts/651 (Array(25, 8)) ''
# /rocks/contacts/652 (Array(27, 8)) ''
# /rocks/contacts/653 (Array(27, 8)) ''
# /rocks/contacts/654 (Array(21, 8)) ''
# /rocks/contacts/655 (Array(29, 8)) ''
# /rocks/contacts/656 (Array(25, 8)) ''
# /rocks/contacts/657 (Array(24, 8)) ''
# /rocks/contacts/658 (Array(26, 8)) ''
# /rocks/contacts/659 (Array(24, 8)) ''
# /rocks/contacts/66 (Array(28, 8)) ''
# /rocks/contacts/660 (Array(23, 8)) ''
# /rocks/contacts/661 (Array(23, 8)) ''
# /rocks/contacts/662 (Array(19, 8)) ''
# /rocks/contacts/663 (Array(18, 8)) ''
# /rocks/contacts/664 (Array(22, 8)) ''
# /rocks/contacts/665 (Array(23, 8)) ''
# /rocks/contacts/666 (Array(23, 8)) ''
# /rocks/contacts/667 (Array(20, 8)) ''
# /rocks/contacts/668 (Array(20, 8)) ''
# /rocks/contacts/669 (Array(47, 8)) ''
# /rocks/contacts/67 (Array(20, 8)) ''
# /rocks/contacts/670 (Array(22, 8)) ''
# /rocks/contacts/671 (Array(20, 8)) ''
# /rocks/contacts/672 (Array(21, 8)) ''
# /rocks/contacts/673 (Array(17, 8)) ''
# /rocks/contacts/674 (Array(26, 8)) ''
# /rocks/contacts/675 (Array(18, 8)) ''
# /rocks/contacts/676 (Array(24, 8)) ''
# /rocks/contacts/677 (Array(30, 8)) ''
# /rocks/contacts/678 (Array(25, 8)) ''
# /rocks/contacts/679 (Array(23, 8)) ''
# /rocks/contacts/68 (Array(27, 8)) ''
# /rocks/contacts/680 (Array(20, 8)) ''
# /rocks/contacts/681 (Array(24, 8)) ''
# /rocks/contacts/682 (Array(23, 8)) ''
# /rocks/contacts/683 (Array(17, 8)) ''
# /rocks/contacts/684 (Array(21, 8)) ''
# /rocks/contacts/685 (Array(26, 8)) ''
# /rocks/contacts/686 (Array(21, 8)) ''
# /rocks/contacts/687 (Array(25, 8)) ''
# /rocks/contacts/688 (Array(20, 8)) ''
# /rocks/contacts/689 (Array(19, 8)) ''
# /rocks/contacts/69 (Array(24, 8)) ''
# /rocks/contacts/690 (Array(19, 8)) ''
# /rocks/contacts/691 (Array(22, 8)) ''
# /rocks/contacts/692 (Array(24, 8)) ''
# /rocks/contacts/693 (Array(20, 8)) ''
# /rocks/contacts/694 (Array(26, 8)) ''
# /rocks/contacts/695 (Array(27, 8)) ''
# /rocks/contacts/696 (Array(21, 8)) ''
# /rocks/contacts/697 (Array(28, 8)) ''
# /rocks/contacts/698 (Array(23, 8)) ''
# /rocks/contacts/699 (Array(27, 8)) ''
# /rocks/contacts/7 (Array(26, 8)) ''
# /rocks/contacts/70 (Array(22, 8)) ''
# /rocks/contacts/700 (Array(24, 8)) ''
# /rocks/contacts/701 (Array(38, 8)) ''
# /rocks/contacts/702 (Array(21, 8)) ''
# /rocks/contacts/703 (Array(31, 8)) ''
# /rocks/contacts/704 (Array(30, 8)) ''
# /rocks/contacts/705 (Array(26, 8)) ''
# /rocks/contacts/706 (Array(17, 8)) ''
# /rocks/contacts/707 (Array(21, 8)) ''
# /rocks/contacts/708 (Array(19, 8)) ''
# /rocks/contacts/709 (Array(20, 8)) ''
# /rocks/contacts/71 (Array(25, 8)) ''
# /rocks/contacts/710 (Array(25, 8)) ''
# /rocks/contacts/711 (Array(25, 8)) ''
# /rocks/contacts/712 (Array(19, 8)) ''
# /rocks/contacts/713 (Array(18, 8)) ''
# /rocks/contacts/714 (Array(26, 8)) ''
# /rocks/contacts/715 (Array(26, 8)) ''
# /rocks/contacts/716 (Array(25, 8)) ''
# /rocks/contacts/717 (Array(22, 8)) ''
# /rocks/contacts/718 (Array(17, 8)) ''
# /rocks/contacts/719 (Array(36, 8)) ''
# /rocks/contacts/72 (Array(20, 8)) ''
# /rocks/contacts/720 (Array(28, 8)) ''
# /rocks/contacts/721 (Array(26, 8)) ''
# /rocks/contacts/722 (Array(27, 8)) ''
# /rocks/contacts/723 (Array(40, 8)) ''
# /rocks/contacts/724 (Array(29, 8)) ''
# /rocks/contacts/725 (Array(20, 8)) ''
# /rocks/contacts/726 (Array(21, 8)) ''
# /rocks/contacts/727 (Array(18, 8)) ''
# /rocks/contacts/728 (Array(27, 8)) ''
# /rocks/contacts/729 (Array(19, 8)) ''
# /rocks/contacts/73 (Array(48, 8)) ''
# /rocks/contacts/730 (Array(23, 8)) ''
# /rocks/contacts/731 (Array(30, 8)) ''
# /rocks/contacts/732 (Array(26, 8)) ''
# /rocks/contacts/733 (Array(33, 8)) ''
# /rocks/contacts/734 (Array(17, 8)) ''
# /rocks/contacts/735 (Array(20, 8)) ''
# /rocks/contacts/736 (Array(21, 8)) ''
# /rocks/contacts/737 (Array(24, 8)) ''
# /rocks/contacts/738 (Array(29, 8)) ''
# /rocks/contacts/739 (Array(23, 8)) ''
# /rocks/contacts/74 (Array(23, 8)) ''
# /rocks/contacts/740 (Array(19, 8)) ''
# /rocks/contacts/741 (Array(24, 8)) ''
# /rocks/contacts/742 (Array(22, 8)) ''
# /rocks/contacts/743 (Array(18, 8)) ''
# /rocks/contacts/744 (Array(18, 8)) ''
# /rocks/contacts/745 (Array(24, 8)) ''
# /rocks/contacts/746 (Array(23, 8)) ''
# /rocks/contacts/747 (Array(19, 8)) ''
# /rocks/contacts/748 (Array(57, 8)) ''
# /rocks/contacts/749 (Array(23, 8)) ''
# /rocks/contacts/75 (Array(19, 8)) ''
# /rocks/contacts/750 (Array(17, 8)) ''
# /rocks/contacts/751 (Array(27, 8)) ''
# /rocks/contacts/752 (Array(22, 8)) ''
# /rocks/contacts/753 (Array(34, 8)) ''
# /rocks/contacts/754 (Array(21, 8)) ''
# /rocks/contacts/755 (Array(26, 8)) ''
# /rocks/contacts/756 (Array(31, 8)) ''
# /rocks/contacts/757 (Array(22, 8)) ''
# /rocks/contacts/758 (Array(26, 8)) ''
# /rocks/contacts/759 (Array(24, 8)) ''
# /rocks/contacts/76 (Array(23, 8)) ''
# /rocks/contacts/760 (Array(21, 8)) ''
# /rocks/contacts/761 (Array(20, 8)) ''
# /rocks/contacts/762 (Array(47, 8)) ''
# /rocks/contacts/763 (Array(23, 8)) ''
# /rocks/contacts/764 (Array(20, 8)) ''
# /rocks/contacts/765 (Array(30, 8)) ''
# /rocks/contacts/766 (Array(21, 8)) ''
# /rocks/contacts/767 (Array(23, 8)) ''
# /rocks/contacts/768 (Array(23, 8)) ''
# /rocks/contacts/769 (Array(18, 8)) ''
# /rocks/contacts/77 (Array(24, 8)) ''
# /rocks/contacts/770 (Array(28, 8)) ''
# /rocks/contacts/771 (Array(20, 8)) ''
# /rocks/contacts/772 (Array(19, 8)) ''
# /rocks/contacts/773 (Array(24, 8)) ''
# /rocks/contacts/774 (Array(23, 8)) ''
# /rocks/contacts/775 (Array(43, 8)) ''
# /rocks/contacts/776 (Array(26, 8)) ''
# /rocks/contacts/777 (Array(45, 8)) ''
# /rocks/contacts/778 (Array(21, 8)) ''
# /rocks/contacts/779 (Array(21, 8)) ''
# /rocks/contacts/78 (Array(25, 8)) ''
# /rocks/contacts/780 (Array(27, 8)) ''
# /rocks/contacts/781 (Array(24, 8)) ''
# /rocks/contacts/782 (Array(23, 8)) ''
# /rocks/contacts/783 (Array(22, 8)) ''
# /rocks/contacts/784 (Array(19, 8)) ''
# /rocks/contacts/785 (Array(24, 8)) ''
# /rocks/contacts/786 (Array(44, 8)) ''
# /rocks/contacts/787 (Array(21, 8)) ''
# /rocks/contacts/788 (Array(23, 8)) ''
# /rocks/contacts/789 (Array(27, 8)) ''
# /rocks/contacts/79 (Array(27, 8)) ''
# /rocks/contacts/790 (Array(22, 8)) ''
# /rocks/contacts/791 (Array(23, 8)) ''
# /rocks/contacts/792 (Array(25, 8)) ''
# /rocks/contacts/793 (Array(21, 8)) ''
# /rocks/contacts/794 (Array(24, 8)) ''
# /rocks/contacts/795 (Array(23, 8)) ''
# /rocks/contacts/796 (Array(26, 8)) ''
# /rocks/contacts/797 (Array(18, 8)) ''
# /rocks/contacts/798 (Array(23, 8)) ''
# /rocks/contacts/799 (Array(21, 8)) ''
# /rocks/contacts/8 (Array(27, 8)) ''
# /rocks/contacts/80 (Array(27, 8)) ''
# /rocks/contacts/800 (Array(26, 8)) ''
# /rocks/contacts/801 (Array(25, 8)) ''
# /rocks/contacts/802 (Array(19, 8)) ''
# /rocks/contacts/803 (Array(33, 8)) ''
# /rocks/contacts/804 (Array(26, 8)) ''
# /rocks/contacts/805 (Array(25, 8)) ''
# /rocks/contacts/806 (Array(19, 8)) ''
# /rocks/contacts/807 (Array(24, 8)) ''
# /rocks/contacts/808 (Array(27, 8)) ''
# /rocks/contacts/809 (Array(25, 8)) ''
# /rocks/contacts/81 (Array(18, 8)) ''
# /rocks/contacts/810 (Array(19, 8)) ''
# /rocks/contacts/811 (Array(20, 8)) ''
# /rocks/contacts/812 (Array(24, 8)) ''
# /rocks/contacts/813 (Array(22, 8)) ''
# /rocks/contacts/814 (Array(26, 8)) ''
# /rocks/contacts/815 (Array(29, 8)) ''
# /rocks/contacts/816 (Array(17, 8)) ''
# /rocks/contacts/817 (Array(24, 8)) ''
# /rocks/contacts/818 (Array(20, 8)) ''
# /rocks/contacts/819 (Array(23, 8)) ''
# /rocks/contacts/82 (Array(20, 8)) ''
# /rocks/contacts/820 (Array(26, 8)) ''
# /rocks/contacts/821 (Array(18, 8)) ''
# /rocks/contacts/822 (Array(23, 8)) ''
# /rocks/contacts/823 (Array(25, 8)) ''
# /rocks/contacts/824 (Array(25, 8)) ''
# /rocks/contacts/825 (Array(23, 8)) ''
# /rocks/contacts/826 (Array(24, 8)) ''
# /rocks/contacts/827 (Array(20, 8)) ''
# /rocks/contacts/828 (Array(17, 8)) ''
# /rocks/contacts/829 (Array(18, 8)) ''
# /rocks/contacts/83 (Array(27, 8)) ''
# /rocks/contacts/830 (Array(26, 8)) ''
# /rocks/contacts/831 (Array(20, 8)) ''
# /rocks/contacts/832 (Array(26, 8)) ''
# /rocks/contacts/833 (Array(24, 8)) ''
# /rocks/contacts/834 (Array(21, 8)) ''
# /rocks/contacts/835 (Array(22, 8)) ''
# /rocks/contacts/836 (Array(21, 8)) ''
# /rocks/contacts/837 (Array(22, 8)) ''
# /rocks/contacts/838 (Array(19, 8)) ''
# /rocks/contacts/839 (Array(27, 8)) ''
# /rocks/contacts/84 (Array(20, 8)) ''
# /rocks/contacts/840 (Array(23, 8)) ''
# /rocks/contacts/841 (Array(26, 8)) ''
# /rocks/contacts/842 (Array(19, 8)) ''
# /rocks/contacts/843 (Array(22, 8)) ''
# /rocks/contacts/844 (Array(22, 8)) ''
# /rocks/contacts/845 (Array(25, 8)) ''
# /rocks/contacts/846 (Array(21, 8)) ''
# /rocks/contacts/847 (Array(20, 8)) ''
# /rocks/contacts/848 (Array(24, 8)) ''
# /rocks/contacts/849 (Array(16, 8)) ''
# /rocks/contacts/85 (Array(20, 8)) ''
# /rocks/contacts/850 (Array(23, 8)) ''
# /rocks/contacts/851 (Array(22, 8)) ''
# /rocks/contacts/852 (Array(28, 8)) ''
# /rocks/contacts/853 (Array(17, 8)) ''
# /rocks/contacts/854 (Array(18, 8)) ''
# /rocks/contacts/855 (Array(20, 8)) ''
# /rocks/contacts/856 (Array(24, 8)) ''
# /rocks/contacts/857 (Array(21, 8)) ''
# /rocks/contacts/858 (Array(24, 8)) ''
# /rocks/contacts/859 (Array(25, 8)) ''
# /rocks/contacts/86 (Array(18, 8)) ''
# /rocks/contacts/860 (Array(24, 8)) ''
# /rocks/contacts/861 (Array(20, 8)) ''
# /rocks/contacts/862 (Array(19, 8)) ''
# /rocks/contacts/863 (Array(23, 8)) ''
# /rocks/contacts/864 (Array(22, 8)) ''
# /rocks/contacts/865 (Array(27, 8)) ''
# /rocks/contacts/866 (Array(20, 8)) ''
# /rocks/contacts/867 (Array(26, 8)) ''
# /rocks/contacts/868 (Array(19, 8)) ''
# /rocks/contacts/869 (Array(17, 8)) ''
# /rocks/contacts/87 (Array(22, 8)) ''
# /rocks/contacts/870 (Array(25, 8)) ''
# /rocks/contacts/871 (Array(25, 8)) ''
# /rocks/contacts/872 (Array(17, 8)) ''
# /rocks/contacts/873 (Array(25, 8)) ''
# /rocks/contacts/874 (Array(19, 8)) ''
# /rocks/contacts/875 (Array(23, 8)) ''
# /rocks/contacts/876 (Array(25, 8)) ''
# /rocks/contacts/877 (Array(26, 8)) ''
# /rocks/contacts/878 (Array(22, 8)) ''
# /rocks/contacts/879 (Array(19, 8)) ''
# /rocks/contacts/88 (Array(18, 8)) ''
# /rocks/contacts/880 (Array(28, 8)) ''
# /rocks/contacts/881 (Array(25, 8)) ''
# /rocks/contacts/882 (Array(19, 8)) ''
# /rocks/contacts/883 (Array(23, 8)) ''
# /rocks/contacts/884 (Array(26, 8)) ''
# /rocks/contacts/885 (Array(26, 8)) ''
# /rocks/contacts/886 (Array(27, 8)) ''
# /rocks/contacts/887 (Array(18, 8)) ''
# /rocks/contacts/888 (Array(31, 8)) ''
# /rocks/contacts/889 (Array(19, 8)) ''
# /rocks/contacts/89 (Array(19, 8)) ''
# /rocks/contacts/890 (Array(24, 8)) ''
# /rocks/contacts/891 (Array(30, 8)) ''
# /rocks/contacts/892 (Array(20, 8)) ''
# /rocks/contacts/893 (Array(20, 8)) ''
# /rocks/contacts/894 (Array(26, 8)) ''
# /rocks/contacts/895 (Array(23, 8)) ''
# /rocks/contacts/896 (Array(26, 8)) ''
# /rocks/contacts/897 (Array(30, 8)) ''
# /rocks/contacts/898 (Array(20, 8)) ''
# /rocks/contacts/899 (Array(26, 8)) ''
# /rocks/contacts/9 (Array(21, 8)) ''
# /rocks/contacts/90 (Array(23, 8)) ''
# /rocks/contacts/900 (Array(24, 8)) ''
# /rocks/contacts/901 (Array(22, 8)) ''
# /rocks/contacts/902 (Array(25, 8)) ''
# /rocks/contacts/903 (Array(23, 8)) ''
# /rocks/contacts/904 (Array(27, 8)) ''
# /rocks/contacts/905 (Array(23, 8)) ''
# /rocks/contacts/906 (Array(22, 8)) ''
# /rocks/contacts/907 (Array(21, 8)) ''
# /rocks/contacts/908 (Array(22, 8)) ''
# /rocks/contacts/909 (Array(30, 8)) ''
# /rocks/contacts/91 (Array(29, 8)) ''
# /rocks/contacts/910 (Array(25, 8)) ''
# /rocks/contacts/911 (Array(26, 8)) ''
# /rocks/contacts/912 (Array(27, 8)) ''
# /rocks/contacts/913 (Array(26, 8)) ''
# /rocks/contacts/914 (Array(21, 8)) ''
# /rocks/contacts/915 (Array(20, 8)) ''
# /rocks/contacts/916 (Array(26, 8)) ''
# /rocks/contacts/917 (Array(22, 8)) ''
# /rocks/contacts/918 (Array(21, 8)) ''
# /rocks/contacts/919 (Array(23, 8)) ''
# /rocks/contacts/92 (Array(25, 8)) ''
# /rocks/contacts/920 (Array(21, 8)) ''
# /rocks/contacts/921 (Array(20, 8)) ''
# /rocks/contacts/922 (Array(21, 8)) ''
# /rocks/contacts/923 (Array(22, 8)) ''
# /rocks/contacts/924 (Array(23, 8)) ''
# /rocks/contacts/925 (Array(44, 8)) ''
# /rocks/contacts/926 (Array(20, 8)) ''
# /rocks/contacts/927 (Array(22, 8)) ''
# /rocks/contacts/928 (Array(22, 8)) ''
# /rocks/contacts/929 (Array(19, 8)) ''
# /rocks/contacts/93 (Array(26, 8)) ''
# /rocks/contacts/930 (Array(21, 8)) ''
# /rocks/contacts/931 (Array(19, 8)) ''
# /rocks/contacts/932 (Array(21, 8)) ''
# /rocks/contacts/933 (Array(29, 8)) ''
# /rocks/contacts/934 (Array(23, 8)) ''
# /rocks/contacts/935 (Array(19, 8)) ''
# /rocks/contacts/936 (Array(21, 8)) ''
# /rocks/contacts/937 (Array(25, 8)) ''
# /rocks/contacts/938 (Array(25, 8)) ''
# /rocks/contacts/939 (Array(26, 8)) ''
# /rocks/contacts/94 (Array(22, 8)) ''
# /rocks/contacts/940 (Array(20, 8)) ''
# /rocks/contacts/941 (Array(31, 8)) ''
# /rocks/contacts/942 (Array(25, 8)) ''
# /rocks/contacts/943 (Array(29, 8)) ''
# /rocks/contacts/944 (Array(23, 8)) ''
# /rocks/contacts/945 (Array(26, 8)) ''
# /rocks/contacts/946 (Array(27, 8)) ''
# /rocks/contacts/947 (Array(23, 8)) ''
# /rocks/contacts/948 (Array(23, 8)) ''
# /rocks/contacts/949 (Array(25, 8)) ''
# /rocks/contacts/95 (Array(27, 8)) ''
# /rocks/contacts/950 (Array(25, 8)) ''
# /rocks/contacts/951 (Array(20, 8)) ''
# /rocks/contacts/952 (Array(23, 8)) ''
# /rocks/contacts/953 (Array(22, 8)) ''
# /rocks/contacts/954 (Array(17, 8)) ''
# /rocks/contacts/955 (Array(24, 8)) ''
# /rocks/contacts/956 (Array(20, 8)) ''
# /rocks/contacts/957 (Array(21, 8)) ''
# /rocks/contacts/958 (Array(24, 8)) ''
# /rocks/contacts/959 (Array(21, 8)) ''
# /rocks/contacts/96 (Array(26, 8)) ''
# /rocks/contacts/960 (Array(23, 8)) ''
# /rocks/contacts/961 (Array(20, 8)) ''
# /rocks/contacts/962 (Array(50, 8)) ''
# /rocks/contacts/963 (Array(23, 8)) ''
# /rocks/contacts/964 (Array(25, 8)) ''
# /rocks/contacts/965 (Array(44, 8)) ''
# /rocks/contacts/966 (Array(27, 8)) ''
# /rocks/contacts/967 (Array(30, 8)) ''
# /rocks/contacts/968 (Array(20, 8)) ''
# /rocks/contacts/969 (Array(23, 8)) ''
# /rocks/contacts/97 (Array(21, 8)) ''
# /rocks/contacts/970 (Array(26, 8)) ''
# /rocks/contacts/971 (Array(20, 8)) ''
# /rocks/contacts/972 (Array(21, 8)) ''
# /rocks/contacts/973 (Array(25, 8)) ''
# /rocks/contacts/974 (Array(25, 8)) ''
# /rocks/contacts/975 (Array(47, 8)) ''
# /rocks/contacts/976 (Array(20, 8)) ''
# /rocks/contacts/977 (Array(21, 8)) ''
# /rocks/contacts/978 (Array(18, 8)) ''
# /rocks/contacts/979 (Array(20, 8)) ''
# /rocks/contacts/98 (Array(25, 8)) ''
# /rocks/contacts/980 (Array(22, 8)) ''
# /rocks/contacts/981 (Array(20, 8)) ''
# /rocks/contacts/982 (Array(19, 8)) ''
# /rocks/contacts/983 (Array(22, 8)) ''
# /rocks/contacts/984 (Array(17, 8)) ''
# /rocks/contacts/985 (Array(42, 8)) ''
# /rocks/contacts/986 (Array(23, 8)) ''
# /rocks/contacts/987 (Array(20, 8)) ''
# /rocks/contacts/988 (Array(21, 8)) ''
# /rocks/contacts/989 (Array(28, 8)) ''
# /rocks/contacts/99 (Array(18, 8)) ''
# /rocks/contacts/990 (Array(21, 8)) ''
# /rocks/contacts/991 (Array(19, 8)) ''
# /rocks/contacts/992 (Array(57, 8)) ''
# /rocks/contacts/993 (Array(42, 8)) ''
# /rocks/contacts/994 (Array(28, 8)) ''
# /rocks/contacts/995 (Array(19, 8)) ''
# /rocks/contacts/996 (Array(20, 8)) ''
# /rocks/contacts/997 (Array(27, 8)) ''
# /rocks/contacts/998 (Array(42, 8)) ''
# /rocks/contacts/999 (Array(28, 8)) ''

# %%
#for node in hdf5_file:
#    print(node)

# %%
#for group in hdf5_file.walk_groups():
#    print(group)

# %%
rock = hdf5_file.get_node("/rocks/contacts/100","")
#obj = h5file.get_node("/checkpoints/1400.0","")
#obj = h5file.get_node("/rocks/start_data","")

# %% [markdown]
# ### Accéder au noeud *start_data*

# %%
start_data = hdf5_file.get_node("/rocks/start_data", "")

# %%
start_data
# Out:
# /rocks/start_data (Array(1000, 3)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None

# %%
start_data.shape
# Out:
# (1000, 3)

# %%
start_data.read()
# Out:
# array([[1.9195553e+00, 2.6500000e+03, 1.2094312e+03],
#        [2.1112261e+00, 2.6500000e+03, 1.4173313e+03],
#        [1.4325264e+00, 2.6500000e+03, 7.4259351e+02],
#        ...,
#        [1.2650884e+00, 2.6500000e+03, 6.0364496e+02],
#        [1.6974916e+00, 2.6500000e+03, 9.8535535e+02],
#        [1.6813984e+00, 2.6500000e+03, 9.6983496e+02]], dtype=float32)

# %% [markdown]
# Les données d'entrée sont organisées de la manière suivante:
# - une ligne correspond à un bloc:
#     - la première colonne contient le volume du bloc ($m^3$);
#     - la deuxième colonne contient la densité du bloc;
#     - la troisième colonne contient l'inertie du bloc ($kg.m^2$).
#
# Il y a donc autant de lignes que de blocs simulés. Ici 1000.

# %% [markdown]
# ### Accéder aux points de contact d'un bloc

# %%
bloc = hdf5_file.get_node("/rocks/contacts/0", "")

# %%
bloc
# Out:
# /rocks/contacts/0 (Array(24, 8)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None

# %%
bloc.shape
# Out:
# (24, 8)

# %%
#bloc.read()

# %% [markdown]
# Ce tableau contient les points de contact du bloc avec le terrain naturel:
# - le nombre de ligne varie suivant le bloc sélectionné;
# - les 8 colonnes contiennent dans l'order:
#     - le type de contact:
#         - 0: start
#         - 1: soil
#         - 2: tree
#         - 3: roll tree
#         - 4: roll
#         - 5: stop
#         - 6: out
#         - 7: fly
#         - 8: motion
#     - la distance sur profil $x$ (m);
#     - l'altitude $z$ (m);
#     - la composante horizontale du vecteur vitesse $v_x$ (m/s);
#     - la composante verticale du vecteur vitesse $v_z$ (m/s);
#     - la vitesse de rotation $\dot{\theta}$ (rad/s);
#     - la composante horizontale de la normale au plan de contact $N_x$;
#     - la composante verticale de la normale au plan de contact $N_z$.
